# %%
import streamlit as st
import pandas as pd
import scipy as sp
import numpy as np
from plotnine import *

# %%
gs_URL = st.text_input("Public Google Sheet URL:","https://docs.google.com/spreadsheets/d/1Fx7f6rM5Ce331F9ipsEMn-xRjUKYiR3R_v9IDBusUUY/edit#gid=0") 
googleSheetId = gs_URL.split("spreadsheets/d/")[1].split("/edit")[0]
worksheetName = st.text_input("Sheet Name:","Bivariate")
URL = f'https://docs.google.com/spreadsheets/d/{googleSheetId}/gviz/tq?tqx=out:csv&sheet={worksheetName}'
# Out:
# 2021-10-31 14:52:52.819
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\harmk\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
df = pd.read_csv(URL)
df = df.dropna(axis=1, how="all")
sdf = df[['Height','Weight']]
fsdf = sdf
lrplot = ggplot(fsdf) + coord_fixed(ratio = .1)
lrplot = lrplot + geom_point(aes(x=fsdf['Height'],y=fsdf['Weight'])) 
lrplot
# Out:
# <ggplot: (118665195081)>

# %%
sp.stats.t.ppf(.025,98)
# Out:
# -1.9844674544266925
